# %%
import os
from youtube_transcript_api import YouTubeTranscriptApi
from googleapiclient.discovery import build
from dotenv import load_dotenv
import re
from typing import List, Optional
from datetime import datetime

# Load environment variables
load_dotenv()

def get_youtube_client():
    """Create and return a YouTube API client"""
    api_key = os.getenv('YOUTUBE_API_KEY')
    if not api_key:
        raise ValueError("YouTube API key not found. Please set YOUTUBE_API_KEY in your .env file")
    return build('youtube', 'v3', developerKey=api_key)

def extract_playlist_videos(playlist_url: str, exclude_pattern: str = "Naruhodo Entrevista") -> List[str]:
    """
    Extract all video URLs from a YouTube playlist,
    excluding videos with titles matching the exclude pattern.
    """
    try:
        # Extract playlist ID from URL
        playlist_id = re.search(r'list=([^&]+)', playlist_url)
        if not playlist_id:
            raise ValueError("Invalid playlist URL. Must contain 'list=' parameter")
        playlist_id = playlist_id.group(1)
        
        youtube = get_youtube_client()
        filtered_urls = []
        excluded_count = 0
        included_count = 0
        next_page_token = None
        
        print("Processing playlist...")
        
        while True:
            request = youtube.playlistItems().list(
                part="snippet",
                playlistId=playlist_id,
                maxResults=50,
                pageToken=next_page_token
            )
            response = request.execute()
            
            for item in response['items']:
                try:
                    video_id = item['snippet']['resourceId']['videoId']
                    title = item['snippet']['title']
                    url = f"https://www.youtube.com/watch?v={video_id}"
                    
                    if exclude_pattern and exclude_pattern in title:
                        excluded_count += 1
                        print(f"Excluding: {title}")
                    else:
                        filtered_urls.append(url)
                        included_count += 1
                        print(f"Including: {title}")
                        
                except Exception as e:
                    print(f"Error processing video: {str(e)}")
                    continue
            
            next_page_token = response.get('nextPageToken')
            if not next_page_token:
                break
        
        print(f"\nTotal videos to process: {included_count}")
        print(f"Total videos excluded: {excluded_count}")
        
        return filtered_urls
    
    except Exception as e:
        print(f"Error extracting playlist: {str(e)}")
        return []

def extract_youtube_transcript(video_url: str, output_dir: str = "transcripts") -> Optional[str]:
    """Extract transcript from a YouTube video"""
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    
    try:
        # Extract video ID
        if "youtube.com" in video_url:
            video_id = video_url.split("v=")[1].split("&")[0]
        elif "youtu.be" in video_url:
            video_id = video_url.split("/")[-1].split("?")[0]
        else:
            print(f"Invalid YouTube URL: {video_url}")
            return None
        
        # Get video details
        youtube = get_youtube_client()
        video_response = youtube.videos().list(
            part="snippet",
            id=video_id
        ).execute()
        
        if not video_response['items']:
            print(f"Video not found: {video_id}")
            return None
            
        video_title = video_response['items'][0]['snippet']['title']
        
        # Get transcript
        transcript_list = None
        language_code = None
        
        # Try to get Portuguese transcript (including auto-generated)
        try:
            transcript_list = YouTubeTranscriptApi.get_transcript(video_id, languages=['pt'])
            language_code = 'pt'
            print("Using Portuguese transcript")
        except:
            try:
                # Try auto-generated Portuguese
                transcript_list = YouTubeTranscriptApi.get_transcript(video_id, languages=['pt-PT', 'pt-BR'])
                language_code = 'pt-auto'
                print("Using auto-generated Portuguese transcript")
            except Exception as e:
                print(f"Could not get Portuguese transcript: {str(e)}")
                return None
        
        if not transcript_list:
            print(f"No transcript available for: {video_title}")
            return None
        
        # Format transcript
        formatted_transcript = []
        formatted_transcript.append(f"Title: {video_title}")
        formatted_transcript.append(f"URL: {video_url}")
        formatted_transcript.append(f"Language: {language_code}")
        formatted_transcript.append(f"Extracted on: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
        formatted_transcript.append("=" * 80)
        formatted_transcript.append("")  # Empty line
        
        # Process transcript entries
        for entry in transcript_list:
            start = float(entry['start'])
            minutes = int(start // 60)
            seconds = int(start % 60)
            timestamp = f"[{minutes:02d}:{seconds:02d}]"
            text = str(entry['text']).strip()
            formatted_transcript.append(f"{timestamp} {text}\n")
        
        # Save to file
        safe_title = "".join([c if c.isalnum() or c in ' -_' else '_' for c in video_title])
        safe_title = safe_title[:50]  # Limit filename length
        output_file = os.path.join(output_dir, f"{safe_title}_{video_id}_{language_code}.txt")
        
        with open(output_file, "w", encoding="utf-8") as f:
            f.write("\n".join(formatted_transcript))
        
        print(f"✓ Transcript saved: {os.path.basename(output_file)}")
        return output_file
        
    except Exception as e:
        print(f"✗ Error extracting transcript for {video_id}: {str(e)}")
        return None

def process_playlist_transcripts(playlist_url: str, exclude_pattern: str = "Naruhodo Entrevista", output_dir: str = "transcripts") -> None:
    """Process all videos in a playlist and download their transcripts"""
    video_urls = extract_playlist_videos(playlist_url, exclude_pattern)
    
    if not video_urls:
        print("No videos to process.")
        return
    
    successful = 0
    failed = 0
    
    print(f"\nDownloading transcripts to '{output_dir}' folder...")
    
    for i, url in enumerate(video_urls):
        print(f"\nProcessing video {i+1}/{len(video_urls)}: {url}")
        transcript_file = extract_youtube_transcript(url, output_dir)
        
        if transcript_file:
            successful += 1
        else:
            failed += 1
    
    print(f"\nProcessing complete!")
    print(f"Successfully downloaded: {successful} transcripts")
    print(f"Failed to download: {failed} transcripts")
    print(f"Transcripts saved to: {os.path.abspath(output_dir)}")

# Example usage
if __name__ == "__main__":
    # Replace with your playlist URL
    playlist_url = "https://www.youtube.com/watch?v=wIPj3OjsFEI&list=PLZjaOxYREinv5RgR-T1ObnljITmsPIZWa"
    process_playlist_transcripts(playlist_url)

# Optional: Test function for single video
def test_transcript_extraction(video_url: str):
    """Test transcript extraction for a single video"""
    try:
        # Extract video ID
        if "youtube.com" in video_url:
            video_id = video_url.split("v=")[1].split("&")[0]
        elif "youtu.be" in video_url:
            video_id = video_url.split("/")[-1].split("?")[0]
        else:
            print(f"Invalid URL: {video_url}")
            return
        
        print(f"Getting transcript for video ID: {video_id}")
            
        # Get list of available transcripts
        transcript_list = YouTubeTranscriptApi.list_transcripts(video_id)
        print("\nAvailable transcripts:")
        for transcript in transcript_list:
            print(f"- {transcript.language_code} ({transcript.language})")
        
        # Try to get Portuguese transcript (including auto-generated)
        transcript = None
        try:
            transcript = YouTubeTranscriptApi.get_transcript(video_id, languages=['pt'])
            print("\nUsing Portuguese transcript")
        except:
            try:
                # Try auto-generated Portuguese
                transcript = YouTubeTranscriptApi.get_transcript(video_id, languages=['pt-PT', 'pt-BR'])
                print("\nUsing auto-generated Portuguese transcript")
            except Exception as e:
                print(f"\nCould not get Portuguese transcript: {str(e)}")
                return
        
        if transcript:
            # Print first few entries
            print("\nFirst 3 entries of transcript:")
            for entry in transcript[:3]:
                minutes = int(float(entry['start']) // 60)
                seconds = int(float(entry['start']) % 60)
                print(f"[{minutes:02d}:{seconds:02d}] {entry['text']}")
            
    except Exception as e:
        print(f"Error: {str(e)}")

# Test with a single video (optional)
# test_url = "https://www.youtube.com/watch?v=YOUR_VIDEO_ID"
# test_transcript_extraction(test_url)
# Out:
# Processing playlist...
# Excluding: Naruhodo Entrevista #39: Mila Massuda
# Including: Naruhodo #438 - O termo "macho alfa" faz sentido? - Parte 2 de 2
# Excluding: Naruhodo Entrevista #38: Jaroslava Valentova
# Including: Naruhodo #437 - O termo "macho alfa" faz sentido? - Parte 1 de 2
# Excluding: Naruhodo Entrevista #37: Roger Carrer
# Including: Naruhodo #436 - A violência faz parte da "natureza humana"?
# Excluding: Naruhodo Entrevista #36: Leandro Leonardo Batista
# Including: Naruhodo #435 - Jogar videogame pode ajudar a curar doenças?
# Excluding: Naruhodo Entrevista #35: Marle Alvarenga
# Including: Naruhodo #434 - Existe amizade entre homens e mulheres? - Parte 2 de 2
# Excluding: Naruhodo Entrevista #34: Paula Pinto e Silva
# Including: Naruhodo #433 - Existe amizade entre homens e mulheres? - Parte 1 de 2
# Excluding: Naruhodo Entrevista #33: André Cravo
# Including: Naruhodo #432 - O uso de cigarros eletrônicos é um problema de saúde pública?
# Excluding: Naruhodo Entrevista #32: Suzana Tanni
# Including: Naruhodo #431 - Empreender se aprende ou é algo que nasce com a pessoa?
# Excluding: Naruhodo Entrevista #31: Lia Rita Bittencourt
# Including: Naruhodo #430 - Por que é tão difícil deixar o rancor de lado?
# Excluding: Naruhodo Entrevista #30: Sabine Pompeia
# Including: Naruhodo #429 - Qual o impacto das bets em nossas vidas?
# Excluding: Naruhodo Entrevista #29: Denise Lellis
# Including: Naruhodo #428 - Prêmio IgNobel 2024 - Parte 2 de 2
# Excluding: Naruhodo Entrevista #28: Ana Bonassa
# Including: Naruhodo #427 - Prêmio IgNobel 2024 - Parte 1 de 2
# Excluding: Naruhodo Entrevista #27: Isabela Venturoza
# Including: Naruhodo #426 - Seu nome pode afetar a forma do seu rosto?
# Excluding: Naruhodo Entrevista #26: Laura Marise de Freitas
# Including: Naruhodo #425 - O que é competitividade? - Parte 2 de 2
# Excluding: Naruhodo Entrevista #25: Marcus Vinicius Nascimento Ferreira
# Including: Naruhodo #424 - O que é competitividade? - Parte 1 de 2
# Excluding: Naruhodo Entrevista #24: Emilio Garcia
# Including: Naruhodo #423 - Lentes que filtram a cor azul são benéficas?
# Excluding: Naruhodo Entrevista #23: Jaqueline Goes
# Including: Naruhodo #422 - Crianças acreditam em contos de fadas?
# Excluding: Naruhodo Entrevista #22: Gabriela Bailas
# Including: Naruhodo #421 - Por que guardamos segredos?
# Excluding: Naruhodo Entrevista #21: Carol Bonomi
# Including: Naruhodo #420 - Maconha faz mal? - Parte 2 de 2
# Excluding: Naruhodo Entrevista #20: Mari Krüger
# Including: Naruhodo #419 - Maconha faz mal? - Parte 1 de 2
# Excluding: Naruhodo Entrevista #19: Edylene Daniel Severiano
# Including: Naruhodo #418 - O que é a birra?
# Including: Naruhodo #32 - Por que precisamos falar urgentemente sobre a Chikungunya?
# Including: Naruhodo #31 - Misturar bebidas alcoólicas piora a ressaca?
# Including: Naruhodo #30 - Por que homens ficam carecas e mulheres não?
# Including: Naruhodo #29 - O que é e como acontece o déjà vu?
# Including: Naruhodo #28 - Qual a diferença entre eficiência, eficácia e efetividade?
# Including: Naruhodo #27 - Bebedores de gin tônica são mais propensos a psicopatias?
# Including: Naruhodo #26 - Meditação faz bem pra saúde, segundo a ciência?
# Including: Naruhodo #25 - Como você resolveria o caso dos 23 prisioneiros?
# Including: Naruhodo #24 - Pessoas preguiçosas são mais inteligentes?
# Including: Naruhodo #23 - Mulheres e homens tem cérebros diferentes?
# Including: Naruhodo #22 - A evolução pode vir a "despuxar" os olhos dos orientais?
# Including: Naruhodo #21 - Comer placenta faz bem?
# Including: Naruhodo #20 - Homeopatia funciona, segundo a ciência?
# Including: Naruhodo #19 - Como você resolveria o mistério da cobertura?
# Including: Naruhodo #17 - A matemática pode ajudar a ganhar na Mega-Sena?
# Including: Naruhodo #18 - É possível adestrar galinhas?
# Including: Naruhodo #16 - O que é e qual o impacto do Movimento Maker?
# Including: Naruhodo #15 - Genes são ativados num corpo depois de morto?
# Including: Naruhodo #14 - Sonhamos todas as noites, até quando não nos lembramos?
# Including: Naruhodo #13 - Como você resolveria este enigma policial?
# Including: Naruhodo #12 - Comer e entrar na água faz mal?
# Including: Naruhodo #11 - Por que os japoneses lêem da direita pra esquerda?
# Including: Naruhodo #10 - Mudar de casa rejuvenesce a memória?
# Including: Naruhodo #9 - Como você resolveria o enigma dos sushis?
# Including: Naruhodo #8 - Comentários dos ouvintes. E a resposta do Desafio Naruhodo!
# Including: Naruhodo #7 - Gatos de três cores são sempre fêmeas?
# Including: Naruhodo #6 - Mulheres que vivem juntas ovulam ao mesmo tempo?
# Including: Naruhodo #5 - É possivel recuperar uma noite mal dormida dormindo mais na noite seguinte?
# Including: Naruhodo #4 - A maior parte dos casos de câncer é culpa do azar?
# Including: Naruhodo #3 - A soma de números positivos pode dar um número negativo?
# Including: Naruhodo #2 - Por que o CD tem o tamanho que tem?
# Including: Naruhodo #1 - Chá de camomila acalma?
# Including: Apresentação Canal Cientística e Podcast Naruhodo no YT
#
# Total videos to process: 441
# Total videos excluded: 39
#
# Downloading transcripts to 'transcripts' folder...
#
# Processing video 1/441: https://www.youtube.com/watch?v=UNKh0Zd3h_k
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _438 - O termo _macho alfa_ faz sentido_ _UNKh0Zd3h_k_pt.txt
#
# Processing video 2/441: https://www.youtube.com/watch?v=Qx1z1R_He_c
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _437 - O termo _macho alfa_ faz sentido_ _Qx1z1R_He_c_pt.txt
#
# Processing video 3/441: https://www.youtube.com/watch?v=AnjRI8sfTJQ
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _436 - A violência faz parte da _natureza_AnjRI8sfTJQ_pt.txt
#
# Processing video 4/441: https://www.youtube.com/watch?v=7Ob___Y97d4
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _435 - Jogar videogame pode ajudar a cura_7Ob___Y97d4_pt.txt
#
# Processing video 5/441: https://www.youtube.com/watch?v=H6D1yCni0rc
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _434 - Existe amizade entre homens e mulh_H6D1yCni0rc_pt.txt
#
# Processing video 6/441: https://www.youtube.com/watch?v=EFVaBfGaowg
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _433 - Existe amizade entre homens e mulh_EFVaBfGaowg_pt.txt
#
# Processing video 7/441: https://www.youtube.com/watch?v=XCiHLKVWDVQ
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _432 - O uso de cigarros eletrônicos é um_XCiHLKVWDVQ_pt.txt
#
# Processing video 8/441: https://www.youtube.com/watch?v=Fsso3SDp650
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _431 - Empreender se aprende ou é algo qu_Fsso3SDp650_pt.txt
#
# Processing video 9/441: https://www.youtube.com/watch?v=u0IesoD4A9A
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _430 - Por que é tão difícil deixar o ran_u0IesoD4A9A_pt.txt
#
# Processing video 10/441: https://www.youtube.com/watch?v=g8lC8YEJRcQ
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _429 - Qual o impacto das bets em nossas _g8lC8YEJRcQ_pt.txt
#
# Processing video 11/441: https://www.youtube.com/watch?v=oZi57dhEgQ0
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _428 - Prêmio IgNobel 2024 - Parte 2 de 2_oZi57dhEgQ0_pt.txt
#
# Processing video 12/441: https://www.youtube.com/watch?v=OC5NmqIbT9o
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _427 - Prêmio IgNobel 2024 - Parte 1 de 2_OC5NmqIbT9o_pt.txt
#
# Processing video 13/441: https://www.youtube.com/watch?v=8p2TLmaXHCE
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _426 - Seu nome pode afetar a forma do se_8p2TLmaXHCE_pt.txt
#
# Processing video 14/441: https://www.youtube.com/watch?v=bMkLimosW0E
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _425 - O que é competitividade_ - Parte 2_bMkLimosW0E_pt.txt
#
# Processing video 15/441: https://www.youtube.com/watch?v=noPHBDvkDUc
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _424 - O que é competitividade_ - Parte 1_noPHBDvkDUc_pt.txt
#
# Processing video 16/441: https://www.youtube.com/watch?v=cYpaucMUZSc
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _423 - Lentes que filtram a cor azul são _cYpaucMUZSc_pt.txt
#
# Processing video 17/441: https://www.youtube.com/watch?v=T1XyI8YURug
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _422 - Crianças acreditam em contos de fa_T1XyI8YURug_pt.txt
#
# Processing video 18/441: https://www.youtube.com/watch?v=fARgZ3WrnVk
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _421 - Por que guardamos segredos__fARgZ3WrnVk_pt.txt
#
# Processing video 19/441: https://www.youtube.com/watch?v=F7wVcGvpoGA
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _420 - Maconha faz mal_ - Parte 2 de 2_F7wVcGvpoGA_pt.txt
#
# Processing video 20/441: https://www.youtube.com/watch?v=cvLTh2bKPiQ
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _419 - Maconha faz mal_ - Parte 1 de 2_cvLTh2bKPiQ_pt.txt
#
# Processing video 21/441: https://www.youtube.com/watch?v=Kywng9Fi7bo
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _418 - O que é a birra__Kywng9Fi7bo_pt.txt
#
# Processing video 22/441: https://www.youtube.com/watch?v=UYJ2eKpZX_4
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _417 - Por que respondemos desastres com _UYJ2eKpZX_4_pt.txt
#
# Processing video 23/441: https://www.youtube.com/watch?v=KSAdxaKvZkI
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _416 - Saunas melhoram a saúde__KSAdxaKvZkI_pt.txt
#
# Processing video 24/441: https://www.youtube.com/watch?v=jqhtO6W03Cc
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _415 - Subir escadas pode ajudar pessoas _jqhtO6W03Cc_pt.txt
#
# Processing video 25/441: https://www.youtube.com/watch?v=OLaBswwX9yM
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _414 - A educação científica salvará o mu_OLaBswwX9yM_pt.txt
#
# Processing video 26/441: https://www.youtube.com/watch?v=335oKVAm99Y
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _413 - Como sabemos se uma coisa é causa _335oKVAm99Y_pt.txt
#
# Processing video 27/441: https://www.youtube.com/watch?v=Towh8afX65Y
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _412 - Por que traímos_ - Parte 2 de 2_Towh8afX65Y_pt.txt
#
# Processing video 28/441: https://www.youtube.com/watch?v=kVruX3Mhxig
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _411 - Por que traímos_ - Parte 1 de 2_kVruX3Mhxig_pt.txt
#
# Processing video 29/441: https://www.youtube.com/watch?v=5WFh2g_epOU
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _410 - Por que cães correm atrás de veícu_5WFh2g_epOU_pt.txt
#
# Processing video 30/441: https://www.youtube.com/watch?v=yil8nUgex2g
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _409 - Por que contamos piadas__yil8nUgex2g_pt.txt
#
# Processing video 31/441: https://www.youtube.com/watch?v=A26IemIBxwQ
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _408 - Por que alguns GIFs parecem ter so_A26IemIBxwQ_pt.txt
#
# Processing video 32/441: https://www.youtube.com/watch?v=qUxluRrHV3E
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _407 - Existe razão sem emoção__qUxluRrHV3E_pt.txt
#
# Processing video 33/441: https://www.youtube.com/watch?v=VltGGsSfNsI
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _406 - As fases do luto têm validade cien_VltGGsSfNsI_pt.txt
#
# Processing video 34/441: https://www.youtube.com/watch?v=Vdu5LRFKa-M
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _405 - O que é o infinito__Vdu5LRFKa-M_pt.txt
#
# Processing video 35/441: https://www.youtube.com/watch?v=pTSZ--4TKMk
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _404 - Por que algumas pessoas gostam de _pTSZ--4TKMk_pt.txt
#
# Processing video 36/441: https://www.youtube.com/watch?v=C-ET1nIP6WM
# Could not get Portuguese transcript:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=C-ET1nIP6WM! This is most likely caused by:
#
# This video is age-restricted. Therefore, you will have to authenticate to be able to retrieve transcripts for it. You will have to provide a cookie to authenticate yourself, as explained in the "Cookie Authentication" section of the README (https://github.com/jdepoix/youtube-transcript-api?tab=readme-ov-file#cookie-authentication)
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
#
# Processing video 37/441: https://www.youtube.com/watch?v=Y9Hw6yw7sw8
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _402 - Prêmio IgNobel 2023 - Parte 2 de 2_Y9Hw6yw7sw8_pt.txt
#
# Processing video 38/441: https://www.youtube.com/watch?v=4ZyMMzb1iSo
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _401 - Prêmio IgNobel 2023 - Parte 1 de 2_4ZyMMzb1iSo_pt.txt
#
# Processing video 39/441: https://www.youtube.com/watch?v=4tPEyrJIKUE
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _400 - Luminar resolverá o enigma que tra_4tPEyrJIKUE_pt.txt
#
# Processing video 40/441: https://www.youtube.com/watch?v=vByA0QVSOb8
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _399 - Assistir à pornografia vicia__vByA0QVSOb8_pt.txt
#
# Processing video 41/441: https://www.youtube.com/watch?v=lTkWGFFkOLo
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _398 - Jejum intermitente funciona__lTkWGFFkOLo_pt.txt
#
# Processing video 42/441: https://www.youtube.com/watch?v=FAZ9BPv_6O4
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _397 - Por que ficamos entediados__FAZ9BPv_6O4_pt.txt
#
# Processing video 43/441: https://www.youtube.com/watch?v=RchVGabxOdo
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _396 - O que fazer frente ao aquecimento _RchVGabxOdo_pt.txt
#
# Processing video 44/441: https://www.youtube.com/watch?v=5bR1RNVo7kM
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _395 - O que é força de vontade__5bR1RNVo7kM_pt.txt
#
# Processing video 45/441: https://www.youtube.com/watch?v=n8h3zC7YLNs
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _394 - A psicologia positiva tem validade_n8h3zC7YLNs_pt.txt
#
# Processing video 46/441: https://www.youtube.com/watch?v=LnSZCHHfoWI
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _393 - A psicologia positiva tem validade_LnSZCHHfoWI_pt.txt
#
# Processing video 47/441: https://www.youtube.com/watch?v=4xHdHpYDTkM
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _392 - Sentimos atração por pessoas parec_4xHdHpYDTkM_pt.txt
#
# Processing video 48/441: https://www.youtube.com/watch?v=tNZAJS7udrY
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _391 - Por que sentimos inveja__tNZAJS7udrY_pt.txt
#
# Processing video 49/441: https://www.youtube.com/watch?v=k98xTfw9gTs
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _390 - Fazer compras para si mesma melhor_k98xTfw9gTs_pt.txt
#
# Processing video 50/441: https://www.youtube.com/watch?v=JKN89pAb10U
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _389 - Por que repetir palavras deixa ela_JKN89pAb10U_pt.txt
#
# Processing video 51/441: https://www.youtube.com/watch?v=xwAEaMyfm0Q
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _388 - Somos bons _ou maus_ por natureza__xwAEaMyfm0Q_pt.txt
#
# Processing video 52/441: https://www.youtube.com/watch?v=Fx37e0PUgY4
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _387 - Somos bons _ou maus_ por natureza__Fx37e0PUgY4_pt.txt
#
# Processing video 53/441: https://www.youtube.com/watch?v=o_4DbSVo9Rk
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _386 - Como é calculada a pontuação do EN_o_4DbSVo9Rk_pt.txt
#
# Processing video 54/441: https://www.youtube.com/watch?v=B0F0nV_dwwI
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _385 - O que é o fenômeno da _melhora da _B0F0nV_dwwI_pt.txt
#
# Processing video 55/441: https://www.youtube.com/watch?v=DhKsqKRHwsw
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _384 - Por que tomamos choque quando enco_DhKsqKRHwsw_pt.txt
#
# Processing video 56/441: https://www.youtube.com/watch?v=PLXIShSn61Q
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _383 - Por que beijamos na boca__PLXIShSn61Q_pt.txt
#
# Processing video 57/441: https://www.youtube.com/watch?v=xI_DO_epNMg
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _382 - Quem ama o feio bonito lhe parece__xI_DO_epNMg_pt.txt
#
# Processing video 58/441: https://www.youtube.com/watch?v=gjS_GVsL3tw
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _381 - Por que temos animais domésticos_ _gjS_GVsL3tw_pt.txt
#
# Processing video 59/441: https://www.youtube.com/watch?v=__zJRw5Fcw8
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _380 - Por que temos animais domésticos_ ___zJRw5Fcw8_pt.txt
#
# Processing video 60/441: https://www.youtube.com/watch?v=fI9rqAJfcUU
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _379 - Como nós nos tornamos nós__fI9rqAJfcUU_pt.txt
#
# Processing video 61/441: https://www.youtube.com/watch?v=lKabJ3lQOHU
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _378 - Por que avisos de perigo não são s_lKabJ3lQOHU_pt.txt
#
# Processing video 62/441: https://www.youtube.com/watch?v=PZVVN9lHeno
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _377 - Aprendemos melhor fazendo pausas__PZVVN9lHeno_pt.txt
#
# Processing video 63/441: https://www.youtube.com/watch?v=0xHqRuLjqPU
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _376 - Como fazer alguém mudar de ideia__0xHqRuLjqPU_pt.txt
#
# Processing video 64/441: https://www.youtube.com/watch?v=N_iB-EHHh5g
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _375 - Por que cutucamos o nariz__N_iB-EHHh5g_pt.txt
#
# Processing video 65/441: https://www.youtube.com/watch?v=mRwy8BhQtGk
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _374 - Ser uma pessoa bagunceira é um pro_mRwy8BhQtGk_pt.txt
#
# Processing video 66/441: https://www.youtube.com/watch?v=8ZaQHTb-o4U
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _373 - Como funciona a carreira de cienti_8ZaQHTb-o4U_pt.txt
#
# Processing video 67/441: https://www.youtube.com/watch?v=ZRwC2GQevIo
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _372 - Qual o impacto do alcoolismo nos d_ZRwC2GQevIo_pt.txt
#
# Processing video 68/441: https://www.youtube.com/watch?v=JAIjJ6E8ZHk
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _371 - Qual o impacto do alcoolismo nos d_JAIjJ6E8ZHk_pt.txt
#
# Processing video 69/441: https://www.youtube.com/watch?v=1BXyvGQ0HCc
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _370 - Homens que acham seu pênis pequeno_1BXyvGQ0HCc_pt.txt
#
# Processing video 70/441: https://www.youtube.com/watch?v=e7yl-9-T6xc
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _369 - É mais difícil fazer amigos quando_e7yl-9-T6xc_pt.txt
#
# Processing video 71/441: https://www.youtube.com/watch?v=Lf_zJEnyzuU
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _368 - Água alcalina faz bem pra saúde__Lf_zJEnyzuU_pt.txt
#
# Processing video 72/441: https://www.youtube.com/watch?v=ouilklEqKAU
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _367 - Estamos ficando mais esquecidos do_ouilklEqKAU_pt.txt
#
# Processing video 73/441: https://www.youtube.com/watch?v=jYJUwNRZWHE
# ...
#
# Processing video 380/441: https://www.youtube.com/watch?v=b9XqhOg-19E
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _61 - Pessoas ricas prestam menos atenção_b9XqhOg-19E_pt.txt
#
# Processing video 381/441: https://www.youtube.com/watch?v=OJWR9nuIwRA
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _60 - Desafio Naruhodo_ Você sabe resolve_OJWR9nuIwRA_pt.txt
#
# Processing video 382/441: https://www.youtube.com/watch?v=hsiiLsFf2To
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _59 - Roupa com proteção solar funciona__hsiiLsFf2To_pt.txt
#
# Processing video 383/441: https://www.youtube.com/watch?v=v83mD8poBwk
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _58 - Por que os horários dos remédios de_v83mD8poBwk_pt.txt
#
# Processing video 384/441: https://www.youtube.com/watch?v=XgYramM4_iQ
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _57 - Por que a gente se arrepia__XgYramM4_iQ_pt.txt
#
# Processing video 385/441: https://www.youtube.com/watch?v=KBvdwK-LwCE
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _56 - Especial_ Rapidinhas do Naruhodo_ -_KBvdwK-LwCE_pt.txt
#
# Processing video 386/441: https://www.youtube.com/watch?v=3uH_S_ECrGg
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _55 - Batata frita é mais benéfica que ba_3uH_S_ECrGg_pt.txt
#
# Processing video 387/441: https://www.youtube.com/watch?v=1f29cJlmjrM
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _54 - Como funciona o efeito placebo__1f29cJlmjrM_pt.txt
#
# Processing video 388/441: https://www.youtube.com/watch?v=bZq4ZknxXqY
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _53 - Desafio Naruhodo_ O que aconteceu n_bZq4ZknxXqY_pt.txt
#
# Processing video 389/441: https://www.youtube.com/watch?v=WMUrKMHJovc
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _52 - No bar_ fazer xixi uma primeira vez_WMUrKMHJovc_pt.txt
#
# Processing video 390/441: https://www.youtube.com/watch?v=aTpTJyZ4Fm8
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _51 - Astrologia_ horóscopo e mapa astral_aTpTJyZ4Fm8_pt.txt
#
# Processing video 391/441: https://www.youtube.com/watch?v=fx9LO60UQSY
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _50 - Frio e gelado têm alguma relação co_fx9LO60UQSY_pt.txt
#
# Processing video 392/441: https://www.youtube.com/watch?v=--Z_ylPXIWc
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _49 - O que causa o vício__--Z_ylPXIWc_pt.txt
#
# Processing video 393/441: https://www.youtube.com/watch?v=ac-IONFXCjo
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _48 - Fazer a pose da Mulher Maravilha au_ac-IONFXCjo_pt.txt
#
# Processing video 394/441: https://www.youtube.com/watch?v=X5xdn0syOfI
# Could not get Portuguese transcript:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=X5xdn0syOfI! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
#
# Processing video 395/441: https://www.youtube.com/watch?v=yooHnPTdQR8
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _46 - Você consegue resolver o caso da mo_yooHnPTdQR8_pt.txt
#
# Processing video 396/441: https://www.youtube.com/watch?v=dE47TRviCVM
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _45 - É possível um motor produzir movime_dE47TRviCVM_pt.txt
#
# Processing video 397/441: https://www.youtube.com/watch?v=1gOxigx3WIc
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _44 - O que é e como funciona o efeito Ma_1gOxigx3WIc_pt.txt
#
# Processing video 398/441: https://www.youtube.com/watch?v=Plwa2xbQ4Vk
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _43 - Especial_ Rapidinhas do Naruhodo_ -_Plwa2xbQ4Vk_pt.txt
#
# Processing video 399/441: https://www.youtube.com/watch?v=_Defw5d94gI
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _42 - Cirandas infantis giram sempre na m__Defw5d94gI_pt.txt
#
# Processing video 400/441: https://www.youtube.com/watch?v=dzNjmuVyh7s
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _41 - Bocejos_ tosses e espirros são _con_dzNjmuVyh7s_pt.txt
#
# Processing video 401/441: https://www.youtube.com/watch?v=hyxfPH3Ky98
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _40 - Como você resolveria o enigma do re_hyxfPH3Ky98_pt.txt
#
# Processing video 402/441: https://www.youtube.com/watch?v=MIKhzU6VNy8
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _39 - A ignorância é uma benção__MIKhzU6VNy8_pt.txt
#
# Processing video 403/441: https://www.youtube.com/watch?v=mb1cg3N_rU8
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _38 - Beber água em copo pequeno mata a s_mb1cg3N_rU8_pt.txt
#
# Processing video 404/441: https://www.youtube.com/watch?v=SuNI-tfbT7k
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _37 - Afinal_ ovo faz bem ou mal__SuNI-tfbT7k_pt.txt
#
# Processing video 405/441: https://www.youtube.com/watch?v=VLZ6EG-3Zsg
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _36 - Mal de Alzheimer e envelhecimento d_VLZ6EG-3Zsg_pt.txt
#
# Processing video 406/441: https://www.youtube.com/watch?v=LBx_pVwgcCU
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _35 - Pessoas absorvem energia umas das o_LBx_pVwgcCU_pt.txt
#
# Processing video 407/441: https://www.youtube.com/watch?v=TRsuubVZzyQ
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _34 - Qual a origem da Black Friday__TRsuubVZzyQ_pt.txt
#
# Processing video 408/441: https://www.youtube.com/watch?v=CJKkC33grPM
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _33 - É tinta ou óleo nas pernas que roda_CJKkC33grPM_pt.txt
#
# Processing video 409/441: https://www.youtube.com/watch?v=eWZnJbw_33I
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _32 - Por que precisamos falar urgentemen_eWZnJbw_33I_pt.txt
#
# Processing video 410/441: https://www.youtube.com/watch?v=tA3OJmEjXMY
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _31 - Misturar bebidas alcoólicas piora a_tA3OJmEjXMY_pt.txt
#
# Processing video 411/441: https://www.youtube.com/watch?v=Zxt96XQGGnc
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _30 - Por que homens ficam carecas e mulh_Zxt96XQGGnc_pt.txt
#
# Processing video 412/441: https://www.youtube.com/watch?v=MsgpP0CWrZs
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _29 - O que é e como acontece o déjà vu__MsgpP0CWrZs_pt.txt
#
# Processing video 413/441: https://www.youtube.com/watch?v=spNpxA8sIis
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _28 - Qual a diferença entre eficiência_ _spNpxA8sIis_pt.txt
#
# Processing video 414/441: https://www.youtube.com/watch?v=l6kkme8WXUA
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _27 - Bebedores de gin tônica são mais pr_l6kkme8WXUA_pt.txt
#
# Processing video 415/441: https://www.youtube.com/watch?v=cqzZlXHtxjk
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _26 - Meditação faz bem pra saúde_ segund_cqzZlXHtxjk_pt.txt
#
# Processing video 416/441: https://www.youtube.com/watch?v=Dza7RnGx36U
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _25 - Como você resolveria o caso dos 23 _Dza7RnGx36U_pt.txt
#
# Processing video 417/441: https://www.youtube.com/watch?v=PHn45UgHUEo
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _24 - Pessoas preguiçosas são mais inteli_PHn45UgHUEo_pt.txt
#
# Processing video 418/441: https://www.youtube.com/watch?v=-bH0VcjpCcI
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _23 - Mulheres e homens tem cérebros dife_-bH0VcjpCcI_pt.txt
#
# Processing video 419/441: https://www.youtube.com/watch?v=PwcNzXXC28Y
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _22 - A evolução pode vir a _despuxar_ os_PwcNzXXC28Y_pt.txt
#
# Processing video 420/441: https://www.youtube.com/watch?v=IuhipdmyA_g
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _21 - Comer placenta faz bem__IuhipdmyA_g_pt.txt
#
# Processing video 421/441: https://www.youtube.com/watch?v=5RKZbHuFXko
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _20 - Homeopatia funciona_ segundo a ciên_5RKZbHuFXko_pt.txt
#
# Processing video 422/441: https://www.youtube.com/watch?v=wxF4lRCf4FA
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _19 - Como você resolveria o mistério da _wxF4lRCf4FA_pt.txt
#
# Processing video 423/441: https://www.youtube.com/watch?v=vNVPQWfkVnM
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _17 - A matemática pode ajudar a ganhar n_vNVPQWfkVnM_pt.txt
#
# Processing video 424/441: https://www.youtube.com/watch?v=2il4DLMwIv8
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _18 - É possível adestrar galinhas__2il4DLMwIv8_pt.txt
#
# Processing video 425/441: https://www.youtube.com/watch?v=HgXmutXn3E0
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _16 - O que é e qual o impacto do Movimen_HgXmutXn3E0_pt.txt
#
# Processing video 426/441: https://www.youtube.com/watch?v=0BiAw5zhnUM
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _15 - Genes são ativados num corpo depois_0BiAw5zhnUM_pt.txt
#
# Processing video 427/441: https://www.youtube.com/watch?v=SAtAJkvtcxk
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _14 - Sonhamos todas as noites_ até quand_SAtAJkvtcxk_pt.txt
#
# Processing video 428/441: https://www.youtube.com/watch?v=w5s4dz3HdZY
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _13 - Como você resolveria este enigma po_w5s4dz3HdZY_pt.txt
#
# Processing video 429/441: https://www.youtube.com/watch?v=DAGOcEJHvsw
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _12 - Comer e entrar na água faz mal__DAGOcEJHvsw_pt.txt
#
# Processing video 430/441: https://www.youtube.com/watch?v=PRtp7MjjfUU
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _11 - Por que os japoneses lêem da direit_PRtp7MjjfUU_pt.txt
#
# Processing video 431/441: https://www.youtube.com/watch?v=cN-DQpSH7R8
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _10 - Mudar de casa rejuvenesce a memória_cN-DQpSH7R8_pt.txt
#
# Processing video 432/441: https://www.youtube.com/watch?v=yVXmojJaGPM
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _9 - Como você resolveria o enigma dos su_yVXmojJaGPM_pt.txt
#
# Processing video 433/441: https://www.youtube.com/watch?v=yB__znaIXrM
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _8 - Comentários dos ouvintes_ E a respos_yB__znaIXrM_pt.txt
#
# Processing video 434/441: https://www.youtube.com/watch?v=WefviHT_tJU
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _7 - Gatos de três cores são sempre fêmea_WefviHT_tJU_pt.txt
#
# Processing video 435/441: https://www.youtube.com/watch?v=sw3W6ugoZrE
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _6 - Mulheres que vivem juntas ovulam ao _sw3W6ugoZrE_pt.txt
#
# Processing video 436/441: https://www.youtube.com/watch?v=E-JN2qagigY
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _5 - É possivel recuperar uma noite mal d_E-JN2qagigY_pt.txt
#
# Processing video 437/441: https://www.youtube.com/watch?v=Uhqhq6POjIU
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _4 - A maior parte dos casos de câncer é _Uhqhq6POjIU_pt.txt
#
# Processing video 438/441: https://www.youtube.com/watch?v=SIXVO5aEaVs
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _3 - A soma de números positivos pode dar_SIXVO5aEaVs_pt.txt
#
# Processing video 439/441: https://www.youtube.com/watch?v=tn-qFPWzVbg
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _2 - Por que o CD tem o tamanho que tem__tn-qFPWzVbg_pt.txt
#
# Processing video 440/441: https://www.youtube.com/watch?v=WuGVCNPJUr8
# Using Portuguese transcript
# ✓ Transcript saved: Naruhodo _1 - Chá de camomila acalma__WuGVCNPJUr8_pt.txt
#
# Processing video 441/441: https://www.youtube.com/watch?v=K-mg1mdFVDc
# Could not get Portuguese transcript:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=K-mg1mdFVDc! This is most likely caused by:
#
# No transcripts were found for any of the requested language codes: ['pt-PT', 'pt-BR']
#
# For this video (K-mg1mdFVDc) transcripts are available in the following languages:
#
# (MANUALLY CREATED)
# None
#
# (GENERATED)
#  - nl ("Dutch (auto-generated)")[TRANSLATABLE]
#
# (TRANSLATION LANGUAGES)
#  - ab ("Abkhazian")
#  - aa ("Afar")
#  - af ("Afrikaans")
#  - ak ("Akan")
#  - sq ("Albanian")
#  - am ("Amharic")
#  - ar ("Arabic")
#  - hy ("Armenian")
#  - as ("Assamese")
#  - ay ("Aymara")
#  - az ("Azerbaijani")
#  - bn ("Bangla")
#  - ba ("Bashkir")
#  - eu ("Basque")
#  - be ("Belarusian")
#  - bho ("Bhojpuri")
#  - bs ("Bosnian")
#  - br ("Breton")
#  - bg ("Bulgarian")
#  - my ("Burmese")
#  - ca ("Catalan")
#  - ceb ("Cebuano")
#  - zh-Hans ("Chinese (Simplified)")
#  - zh-Hant ("Chinese (Traditional)")
#  - co ("Corsican")
#  - hr ("Croatian")
#  - cs ("Czech")
#  - da ("Danish")
#  - dv ("Divehi")
#  - nl ("Dutch")
#  - dz ("Dzongkha")
#  - en ("English")
#  - eo ("Esperanto")
#  - et ("Estonian")
#  - ee ("Ewe")
#  - fo ("Faroese")
#  - fj ("Fijian")
#  - fil ("Filipino")
#  - fi ("Finnish")
#  - fr ("French")
#  - gaa ("Ga")
#  - gl ("Galician")
#  - lg ("Ganda")
#  - ka ("Georgian")
#  - de ("German")
#  - el ("Greek")
#  - gn ("Guarani")
#  - gu ("Gujarati")
#  - ht ("Haitian Creole")
#  - ha ("Hausa")
#  - haw ("Hawaiian")
#  - iw ("Hebrew")
#  - hi ("Hindi")
#  - hmn ("Hmong")
#  - hu ("Hungarian")
#  - is ("Icelandic")
#  - ig ("Igbo")
#  - id ("Indonesian")
#  - iu ("Inuktitut")
#  - ga ("Irish")
#  - it ("Italian")
#  - ja ("Japanese")
#  - jv ("Javanese")
#  - kl ("Kalaallisut")
#  - kn ("Kannada")
#  - kk ("Kazakh")
#  - kha ("Khasi")
#  - km ("Khmer")
#  - rw ("Kinyarwanda")
#  - ko ("Korean")
#  - kri ("Krio")
#  - ku ("Kurdish")
#  - ky ("Kyrgyz")
#  - lo ("Lao")
#  - la ("Latin")
#  - lv ("Latvian")
#  - ln ("Lingala")
#  - lt ("Lithuanian")
#  - lua ("Luba-Lulua")
#  - luo ("Luo")
#  - lb ("Luxembourgish")
#  - mk ("Macedonian")
#  - mg ("Malagasy")
#  - ms ("Malay")
#  - ml ("Malayalam")
#  - mt ("Maltese")
#  - gv ("Manx")
#  - mi ("Māori")
#  - mr ("Marathi")
#  - mn ("Mongolian")
#  - mfe ("Morisyen")
#  - ne ("Nepali")
#  - new ("Newari")
#  - nso ("Northern Sotho")
#  - no ("Norwegian")
#  - ny ("Nyanja")
#  - oc ("Occitan")
#  - or ("Odia")
#  - om ("Oromo")
#  - os ("Ossetic")
#  - pam ("Pampanga")
#  - ps ("Pashto")
#  - fa ("Persian")
#  - pl ("Polish")
#  - pt ("Portuguese")
#  - pt-PT ("Portuguese (Portugal)")
#  - pa ("Punjabi")
#  - qu ("Quechua")
#  - ro ("Romanian")
#  - rn ("Rundi")
#  - ru ("Russian")
#  - sm ("Samoan")
#  - sg ("Sango")
#  - sa ("Sanskrit")
#  - gd ("Scottish Gaelic")
#  - sr ("Serbian")
#  - crs ("Seselwa Creole French")
#  - sn ("Shona")
#  - sd ("Sindhi")
#  - si ("Sinhala")
#  - sk ("Slovak")
#  - sl ("Slovenian")
#  - so ("Somali")
#  - st ("Southern Sotho")
#  - es ("Spanish")
#  - su ("Sundanese")
#  - sw ("Swahili")
#  - ss ("Swati")
#  - sv ("Swedish")
#  - tg ("Tajik")
#  - ta ("Tamil")
#  - tt ("Tatar")
#  - te ("Telugu")
#  - th ("Thai")
#  - bo ("Tibetan")
#  - ti ("Tigrinya")
#  - to ("Tongan")
#  - ts ("Tsonga")
#  - tn ("Tswana")
#  - tum ("Tumbuka")
#  - tr ("Turkish")
#  - tk ("Turkmen")
#  - uk ("Ukrainian")
#  - ur ("Urdu")
#  - ug ("Uyghur")
#  - uz ("Uzbek")
#  - ve ("Venda")
#  - vi ("Vietnamese")
#  - war ("Waray")
#  - cy ("Welsh")
#  - fy ("Western Frisian")
#  - wo ("Wolof")
#  - xh ("Xhosa")
#  - yi ("Yiddish")
#  - yo ("Yoruba")
#  - zu ("Zulu")
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
#
# Processing complete!
# Successfully downloaded: 431 transcripts
# Failed to download: 10 transcripts
# Transcripts saved to: g:\My Drive\Projects\naruhodo_references\references_Link\transcripts
